# %% [markdown]
# # PointNetFull Multi-seed Benchmark Report
#
# Auto-generated report with robust protocol (multi-seeds, early stopping, optional sweep).

# %% [markdown]
# ## Setup
# - mode: `benchmark`
# - sweep: `n/a`
# - seeds: `[1]`
# - epochs_max: `50`
# - batch_size: `32`
# - early_stop_monitor: `val_acc`
# - early_stop_patience: `6`
# - normalize_unit_sphere: `False`
# - use_scheduler: `True`

# %% [markdown]
# ## Ranking by mean(best_val_acc)
# | Rank | Experiment | Runs | best_val_acc (mean+-std) | best_eval_acc (mean+-std) | best_val_loss (mean+-std) | best_epoch (mean+-std) | final_val_acc (mean+-std) | final_train_acc (mean+-std) | mean best per-class acc (mean+-std) |
# |---|---|---|---|---|---|---|---|---|---|
# | 1 | plus_occlusion | 1 | 88.33 +- 0.00 | 88.33 +- 0.00 | 0.3612 +- 0.0000 | 21.00 +- 0.00 | 87.33 +- 0.00 | 93.76 +- 0.00 | 0.8723 +- 0.0000 |
# | 2 | combo_full | 1 | 88.22 +- 0.00 | 88.22 +- 0.00 | 0.3794 +- 0.0000 | 18.00 +- 0.00 | 88.00 +- 0.00 | 91.78 +- 0.00 | 0.8724 +- 0.0000 |
# | 3 | baseline | 1 | 86.45 +- 0.00 | 86.45 +- 0.00 | 0.4277 +- 0.0000 | 10.00 +- 0.00 | 81.61 +- 0.00 | 89.83 +- 0.00 | 0.8561 +- 0.0000 |
# | 4 | plus_jitter | 1 | 86.12 +- 0.00 | 86.12 +- 0.00 | 0.4425 +- 0.0000 | 7.00 +- 0.00 | 83.81 +- 0.00 | 90.00 +- 0.00 | 0.8521 +- 0.0000 |

# %% [markdown]
# ## Ranking by mean(best_eval_acc)
# | Rank | Experiment | Runs | best_eval_acc (mean+-std) | best_val_acc (mean+-std) |
# |---|---|---|---|---|
# | 1 | plus_occlusion | 1 | 88.33 +- 0.00 | 88.33 +- 0.00 |
# | 2 | combo_full | 1 | 88.22 +- 0.00 | 88.22 +- 0.00 |
# | 3 | baseline | 1 | 86.45 +- 0.00 | 86.45 +- 0.00 |
# | 4 | plus_jitter | 1 | 86.12 +- 0.00 | 86.12 +- 0.00 |

# %% [markdown]
# ## Comparative Plots
# (disabled)

# %% [markdown]
# ## Sweep-specific Plots
# (n/a)

# %% [markdown]
# ## Augmentation Galleries
# (disabled)

# %% [markdown]
# ## Error Analysis
# (disabled)

# %% [markdown]
# ## Raw summaries
# - `summaries/run_summary.csv`
# - `summaries/summary_experiments.csv`
# - `summaries/summary_experiments_by_eval.csv`
