# %% [markdown]
# # PointNetFull Detailed Runs

# %% [markdown]
# ## baseline
# - description: RotationZ + Gaussian noise
# - params: `{"noise_std": 0.02, "rot_z": 1.0}`
# - aggregated best_val_acc: 86.45 +- 0.00
# - aggregated best_eval_acc: 86.45 +- 0.00

# %% [markdown]
# | Seed | Epochs Ran | Best Epoch | Best Val Acc | Best Eval Acc | Best Val Loss | Final Val Acc | Final Train Acc | Curve | Confusion |
# |---|---|---|---|---|---|---|---|---|---|
# | 1 | 16 | 10 | 86.45 | 86.45 | 0.4277 | 81.61 | 89.83 | ![curve](/home/nochi/NOCHI/M2_PAR/Apprenyissage_Pointcloud/Pointclouds-classification-with-the-POINTNET-Neural-network/PointNetLab/Code/reports/pointnetfull_aug_suite_20260211_081948/runs/baseline/seed_1/curves.png) | ![cm](/home/nochi/NOCHI/M2_PAR/Apprenyissage_Pointcloud/Pointclouds-classification-with-the-POINTNET-Neural-network/PointNetLab/Code/reports/pointnetfull_aug_suite_20260211_081948/runs/baseline/seed_1/confusion_matrix.png) |

# %% [markdown]
# ## combo_full
# - description: Baseline + scale + translate + jitter + mirror + dropout + occlusion
# - params: `{"dropout_max_ratio": 0.45, "jitter_clip": 0.04, "jitter_sigma": 0.01, "mirror_p": 0.3, "occlusion_p": 0.25, "occlusion_radius": 0.18, "scale_high": 1.2, "scale_low": 0.85, "translate_shift": 0.1}`
# - aggregated best_val_acc: 88.22 +- 0.00
# - aggregated best_eval_acc: 88.22 +- 0.00

# %% [markdown]
# | Seed | Epochs Ran | Best Epoch | Best Val Acc | Best Eval Acc | Best Val Loss | Final Val Acc | Final Train Acc | Curve | Confusion |
# |---|---|---|---|---|---|---|---|---|---|
# | 1 | 24 | 18 | 88.22 | 88.22 | 0.3794 | 88.00 | 91.78 | ![curve](/home/nochi/NOCHI/M2_PAR/Apprenyissage_Pointcloud/Pointclouds-classification-with-the-POINTNET-Neural-network/PointNetLab/Code/reports/pointnetfull_aug_suite_20260211_081948/runs/combo_full/seed_1/curves.png) | ![cm](/home/nochi/NOCHI/M2_PAR/Apprenyissage_Pointcloud/Pointclouds-classification-with-the-POINTNET-Neural-network/PointNetLab/Code/reports/pointnetfull_aug_suite_20260211_081948/runs/combo_full/seed_1/confusion_matrix.png) |

# %% [markdown]
# ## plus_jitter
# - description: Baseline + clipped jitter
# - params: `{"jitter_clip": 0.04, "jitter_sigma": 0.01}`
# - aggregated best_val_acc: 86.12 +- 0.00
# - aggregated best_eval_acc: 86.12 +- 0.00

# %% [markdown]
# | Seed | Epochs Ran | Best Epoch | Best Val Acc | Best Eval Acc | Best Val Loss | Final Val Acc | Final Train Acc | Curve | Confusion |
# |---|---|---|---|---|---|---|---|---|---|
# | 1 | 13 | 7 | 86.12 | 86.12 | 0.4425 | 83.81 | 90.00 | ![curve](/home/nochi/NOCHI/M2_PAR/Apprenyissage_Pointcloud/Pointclouds-classification-with-the-POINTNET-Neural-network/PointNetLab/Code/reports/pointnetfull_aug_suite_20260211_081948/runs/plus_jitter/seed_1/curves.png) | ![cm](/home/nochi/NOCHI/M2_PAR/Apprenyissage_Pointcloud/Pointclouds-classification-with-the-POINTNET-Neural-network/PointNetLab/Code/reports/pointnetfull_aug_suite_20260211_081948/runs/plus_jitter/seed_1/confusion_matrix.png) |

# %% [markdown]
# ## plus_occlusion
# - description: Baseline + random spherical occlusion
# - params: `{"occlusion_p": 0.25, "occlusion_radius": 0.18}`
# - aggregated best_val_acc: 88.33 +- 0.00
# - aggregated best_eval_acc: 88.33 +- 0.00

# %% [markdown]
# | Seed | Epochs Ran | Best Epoch | Best Val Acc | Best Eval Acc | Best Val Loss | Final Val Acc | Final Train Acc | Curve | Confusion |
# |---|---|---|---|---|---|---|---|---|---|
# | 1 | 27 | 21 | 88.33 | 88.33 | 0.3612 | 87.33 | 93.76 | ![curve](/home/nochi/NOCHI/M2_PAR/Apprenyissage_Pointcloud/Pointclouds-classification-with-the-POINTNET-Neural-network/PointNetLab/Code/reports/pointnetfull_aug_suite_20260211_081948/runs/plus_occlusion/seed_1/curves.png) | ![cm](/home/nochi/NOCHI/M2_PAR/Apprenyissage_Pointcloud/Pointclouds-classification-with-the-POINTNET-Neural-network/PointNetLab/Code/reports/pointnetfull_aug_suite_20260211_081948/runs/plus_occlusion/seed_1/confusion_matrix.png) |
