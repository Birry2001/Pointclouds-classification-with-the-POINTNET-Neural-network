# %% [markdown]
# # PointNetFull Detailed Experiment Logs

# %% [markdown]
# ## plus_jitter
# - Description: Baseline + clipped jitter
# - Best val acc: 91.08% (epoch 23)
# - Final val acc: 86.67%
# - Avg epoch time: 265.14s
# - History CSV: `../histories/plus_jitter_history.csv`
# - Checkpoint: `../checkpoints/plus_jitter_best.pt`
# ![curves](../figures/plus_jitter_curves.png)
# ![confusion](../figures/plus_jitter_confusion_matrix.png)

# %% [markdown]
# ## plus_mirror
# - Description: Baseline + random mirror (x/y)
# - Best val acc: 90.75% (epoch 21)
# - Final val acc: 87.56%
# - Avg epoch time: 264.64s
# - History CSV: `../histories/plus_mirror_history.csv`
# - Checkpoint: `../checkpoints/plus_mirror_best.pt`
# ![curves](../figures/plus_mirror_curves.png)
# ![confusion](../figures/plus_mirror_confusion_matrix.png)

# %% [markdown]
# ## plus_occlusion
# - Description: Baseline + random spherical occlusion
# - Best val acc: 90.42% (epoch 23)
# - Final val acc: 89.76%
# - Avg epoch time: 264.86s
# - History CSV: `../histories/plus_occlusion_history.csv`
# - Checkpoint: `../checkpoints/plus_occlusion_best.pt`
# ![curves](../figures/plus_occlusion_curves.png)
# ![confusion](../figures/plus_occlusion_confusion_matrix.png)

# %% [markdown]
# ## baseline
# - Description: RotationZ + Gaussian noise
# - Best val acc: 90.31% (epoch 23)
# - Final val acc: 88.77%
# - Avg epoch time: 264.46s
# - History CSV: `../histories/baseline_history.csv`
# - Checkpoint: `../checkpoints/baseline_best.pt`
# ![curves](../figures/baseline_curves.png)
# ![confusion](../figures/baseline_confusion_matrix.png)

# %% [markdown]
# ## plus_scale
# - Description: Baseline + random isotropic scale
# - Best val acc: 90.31% (epoch 21)
# - Final val acc: 87.33%
# - Avg epoch time: 264.80s
# - History CSV: `../histories/plus_scale_history.csv`
# - Checkpoint: `../checkpoints/plus_scale_best.pt`
# ![curves](../figures/plus_scale_curves.png)
# ![confusion](../figures/plus_scale_confusion_matrix.png)

# %% [markdown]
# ## plus_translate
# - Description: Baseline + random translation
# - Best val acc: 90.31% (epoch 21)
# - Final val acc: 87.56%
# - Avg epoch time: 264.84s
# - History CSV: `../histories/plus_translate_history.csv`
# - Checkpoint: `../checkpoints/plus_translate_best.pt`
# ![curves](../figures/plus_translate_curves.png)
# ![confusion](../figures/plus_translate_confusion_matrix.png)

# %% [markdown]
# ## combo_robust
# - Description: Baseline + scale + translation + point dropout + occlusion
# - Best val acc: 90.20% (epoch 23)
# - Final val acc: 86.23%
# - Avg epoch time: 265.03s
# - History CSV: `../histories/combo_robust_history.csv`
# - Checkpoint: `../checkpoints/combo_robust_best.pt`
# ![curves](../figures/combo_robust_curves.png)
# ![confusion](../figures/combo_robust_confusion_matrix.png)

# %% [markdown]
# ## combo_full
# - Description: Baseline + scale + translation + jitter + mirror + point dropout + occlusion
# - Best val acc: 90.09% (epoch 22)
# - Final val acc: 90.09%
# - Avg epoch time: 265.54s
# - History CSV: `../histories/combo_full_history.csv`
# - Checkpoint: `../checkpoints/combo_full_best.pt`
# ![curves](../figures/combo_full_curves.png)
# ![confusion](../figures/combo_full_confusion_matrix.png)

# %% [markdown]
# ## plus_dropout
# - Description: Baseline + random point dropout
# - Best val acc: 89.65% (epoch 23)
# - Final val acc: 89.43%
# - Avg epoch time: 264.97s
# - History CSV: `../histories/plus_dropout_history.csv`
# - Checkpoint: `../checkpoints/plus_dropout_best.pt`
# ![curves](../figures/plus_dropout_curves.png)
# ![confusion](../figures/plus_dropout_confusion_matrix.png)

# %% [markdown]
# ## combo_geo
# - Description: Baseline + scale + translation + jitter + mirror
# - Best val acc: 88.33% (epoch 22)
# - Final val acc: 86.78%
# - Avg epoch time: 265.27s
# - History CSV: `../histories/combo_geo_history.csv`
# - Checkpoint: `../checkpoints/combo_geo_best.pt`
# ![curves](../figures/combo_geo_curves.png)
# ![confusion](../figures/combo_geo_confusion_matrix.png)
