# %% [markdown]
# # PointNetFull Augmentation Benchmark Report
#
# Automatic campaign report ready for analysis.

# %% [markdown]
# ## Experimental Setup
# - Dataset: `/home/nochi/NOCHI/M2_PAR/Apprenyissage_Pointcloud/Pointclouds-classification-with-the-POINTNET-Neural-network/PointNetLab/data/ModelNet10_PLY`
# - Model: PointNetFull (first 3x3 T-Net only, enonce-compatible)
# - Device: `cuda:0`
# - Epochs per experiment: `2`
# - Batch size: `32`
# - Num workers: `0`
# - Seed: `42`
# - Number of tested augmentation configs: `10`

# %% [markdown]
# ## Ranking by Best Validation Accuracy
# | Rank | Experiment | Best Val Acc (%) | Best Epoch | Avg Epoch Time (s) |
# |---:|---|---:|---:|---:|
# | 1 | combo_full | 76.87 | 2 | 268.53 |
# | 2 | plus_occlusion | 76.10 | 2 | 268.95 |
# | 3 | plus_mirror | 75.88 | 2 | 266.18 |
# | 4 | plus_translate | 75.66 | 2 | 268.46 |
# | 5 | plus_jitter | 69.05 | 2 | 267.69 |
# | 6 | combo_robust | 67.29 | 2 | 267.07 |
# | 7 | plus_scale | 65.31 | 2 | 267.30 |
# | 8 | baseline | 64.21 | 2 | 265.96 |
# | 9 | combo_geo | 61.89 | 2 | 268.61 |
# | 10 | plus_dropout | 58.48 | 1 | 267.20 |

# %% [markdown]
# ## Augmentation Visual Preview
# ![augmentation_gallery](../figures/augmentation_gallery.png)

# %% [markdown]
# ## Global Comparison Figures
# ![best_val_bar](../figures/global_best_val_accuracy_bar.png)
# ![acc_vs_time](../figures/global_accuracy_vs_time.png)
# ![val_curves](../figures/global_val_accuracy_curves.png)

# %% [markdown]
# ## Best Experiment Diagnostics
# - Best setup: `combo_full`
# - Best val accuracy: `76.87%`
# - Best epoch: `2`
# ![best_curves](../figures/combo_full_curves.png)
# ![best_cm](../figures/combo_full_confusion_matrix.png)

# %% [markdown]
# ## Raw Artifacts
# - Summary CSV: `../experiment_summary.csv`
# - Summary JSON: `../experiment_summary.json`
# - Per-experiment history CSV/JSON are in `../histories/`.
# - Best checkpoints are in `../checkpoints/`.
